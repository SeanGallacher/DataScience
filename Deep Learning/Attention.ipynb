# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clone()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext spacy
# !python -m spacy download en
# !python -m spacy download es
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Requirement already satisfied: torchtext in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (2.2.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.21.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext) (4.62.3)
# Requirement already satisfied: torch==1.10.0 in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.10.0+cu111)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.0->torchtext) (3.10.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (7.4.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy) (4.11.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy) (3.7.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (3.0.4)
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 35.4 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.21.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.11.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')
# Collecting es_core_news_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.2.5/es_core_news_sm-2.2.5.tar.gz (16.2 MB)
#      |████████████████████████████████| 16.2 MB 19.5 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from es_core_news_sm==2.2.5) (2.2.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.9.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (0.4.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.0)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (7.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (57.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (4.62.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.21.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (2.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->es_core_news_sm==2.2.5) (1.0.6)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (4.11.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->es_core_news_sm==2.2.5) (2021.10.8)
# ✔ Download and installation successful
# You can now load the model via spacy.load('es_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/es_core_news_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/es
# You can now load the model via spacy.load('es')
# --2022-02-15 19:51:03--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.02s
#
# 2022-02-15 19:51:03 (330 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2022-02-15 19:51:03--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.02s
#
# 2022-02-15 19:51:03 (331 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# #Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))
    
class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)
    
class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))
    
def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)


    
class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)
        
    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)
    
class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)
 
    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)
    
def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ##Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
###query comes from previous decode layer (input sequence)
###key-value pair, comes from the output of the encoder 
###self attention is where queery, key, value is coming from the same input 
### encoders last output 
### torch.bmm, torch.mm, and torch.matmul
## torch.t, torch.transpose, and torch.permute.
### Matries, sequence Legnht X embeding values, (key and value can have different embending dimension )
def attention(query, key, value, mask):
    dk = key.shape[-1]
    # scores = QK^T/scale
    scores = torch.matmul(query, torch.transpose(key,1,2))/np.sqrt(dk)

    SM = nn.Softmax(dim=2)
    ###compute attetnion
    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)
    # output = softmax(scores)(V)
    Attention = torch.matmul(SM(scores), value)
    
    return Attention

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()
        # Implement Multi-head attention mechanism
        self.h = h

        # Make an attention head (linear layers for q, k, and v)
        self.Wqs = nn.ModuleList()
        self.Wks = nn.ModuleList()
        self.Wvs = nn.ModuleList()

        dh = int(d_model/h)

        for i in range(h):
          Wq = nn.Linear(d_model,dh)
          self.Wqs.append(Wq)
          Wk = nn.Linear(d_model,dh)
          self.Wks.append(Wk)
          Wv = nn.Linear(d_model,dh)
          self.Wqs.append(Wq)
        # Make h copies of the attention head (Hint: See the `clone()` helper function)
        self.Wo = nn.Linear(d_model, d_model)
        # etc.

    def forward(self, query, key, value, mask):
        # For each attention head
            # Pass the query, key, value through their respective layers
            # Compute scaled dot-product attention on the output
        # etc.
        multiHead = []
        for i in range(self.h):
          multiHead.append(attention(self.Wqs[i](query) ,self.Wks[i](key) ,self.Wqs[i](value),mask))
        output = self.Wo(torch.cat(multiHead, dim=2))
        return output

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)
        
    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)], 
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()
        
        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy
        
        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn), 
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)
        
    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)
    
    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)
    
    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()
    
    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask
    
    
global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext.legacy import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es')
spacy_en = spacy.load('en')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD, 
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
spanish_text = open('./spanish','r')
english_text = open('./english', 'r')
english_lines = list(english_text)
spanish_lines = list(spanish_text)

fields = (["src", SRC], ["trg", TGT])
examples = [torchtext.legacy.data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = torchtext.legacy.data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and 
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt
        
    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)), 
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)
            
        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)

    
def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg, 
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ##Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=True)
    valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train=False)

    model_opt = torch.optim.Adam(model.parameters(), lr=5e-4)
    for epoch in range(n_epochs):
        model.train()
        run_epoch((rebatch(pad_idx, b) for b in train_iter), 
                  model, 
                  LossFunction(model.generator, criterion, model_opt))
        model.eval()
scope()
# Out:
# MADE IT
# Epoch Step: 1 Loss: 8.690294 Tokens per Sec: 3972.052246
# Epoch Step: 51 Loss: 5.961043 Tokens per Sec: 9863.338867
# Epoch Step: 101 Loss: 5.744642 Tokens per Sec: 9814.584961
# Epoch Step: 151 Loss: 5.101132 Tokens per Sec: 10325.293945
# Epoch Step: 201 Loss: 5.433235 Tokens per Sec: 10032.913086
# Epoch Step: 251 Loss: 5.058882 Tokens per Sec: 10193.736328
# Epoch Step: 301 Loss: 4.651732 Tokens per Sec: 10079.030273
# Epoch Step: 351 Loss: 4.767724 Tokens per Sec: 10034.470703
# Epoch Step: 401 Loss: 4.396621 Tokens per Sec: 10217.691406
# Epoch Step: 451 Loss: 4.872485 Tokens per Sec: 10177.407227
# Epoch Step: 501 Loss: 4.659668 Tokens per Sec: 9128.850586
# Epoch Step: 551 Loss: 4.088608 Tokens per Sec: 9706.578125
# Epoch Step: 601 Loss: 4.109283 Tokens per Sec: 9553.329102
# Epoch Step: 651 Loss: 4.652823 Tokens per Sec: 9440.202148
# Epoch Step: 701 Loss: 4.499880 Tokens per Sec: 9312.949219
# Epoch Step: 751 Loss: 4.260208 Tokens per Sec: 9864.587891
# Epoch Step: 801 Loss: 4.005435 Tokens per Sec: 10290.648438
# Epoch Step: 851 Loss: 4.239173 Tokens per Sec: 9417.017578
# Epoch Step: 901 Loss: 3.888765 Tokens per Sec: 8537.525391
# Epoch Step: 951 Loss: 3.999917 Tokens per Sec: 8493.834961
# Epoch Step: 1001 Loss: 3.936907 Tokens per Sec: 8768.839844
# Epoch Step: 1051 Loss: 3.974766 Tokens per Sec: 8691.300781
# Epoch Step: 451 Loss: 2.105149 Tokens per Sec: 8572.694336
# Epoch Step: 501 Loss: 2.416079 Tokens per Sec: 8659.642578
# Epoch Step: 551 Loss: 2.509358 Tokens per Sec: 8814.202148
# Epoch Step: 601 Loss: 2.505524 Tokens per Sec: 8516.750000
# Epoch Step: 651 Loss: 2.284252 Tokens per Sec: 8546.390625
# Epoch Step: 701 Loss: 2.412808 Tokens per Sec: 8810.634766
# Epoch Step: 751 Loss: 2.610247 Tokens per Sec: 8734.087891
# Epoch Step: 801 Loss: 1.951799 Tokens per Sec: 8592.840820
# Epoch Step: 851 Loss: 2.487036 Tokens per Sec: 8757.698242
# Epoch Step: 901 Loss: 1.798610 Tokens per Sec: 8679.663086
# Epoch Step: 951 Loss: 2.312602 Tokens per Sec: 8738.808594
# Epoch Step: 1001 Loss: 2.753690 Tokens per Sec: 8308.279297
# Epoch Step: 1051 Loss: 2.425804 Tokens per Sec: 8361.429688
# Epoch Step: 1101 Loss: 2.060069 Tokens per Sec: 8315.365234
# Epoch Step: 1151 Loss: 1.073946 Tokens per Sec: 8411.487305
# Epoch Step: 1201 Loss: 2.063139 Tokens per Sec: 8444.410156
# Epoch Step: 1251 Loss: 2.864579 Tokens per Sec: 8445.299805
# Epoch Step: 1301 Loss: 2.250082 Tokens per Sec: 8578.259766

# %% [markdown]
# ## Translate

# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask, 
                           Variable(ys), 
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys, 
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)
    
for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask, 
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()
    
    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	Libro de Mormón
# Translation:	Book of Mormon
# Target:		Book of Mormon
#
# Spanish:	Lo sé .
# Translation:	I know .
# Target:		I Know It .
#
# Spanish:	2 Corintios 11:3 .
# Translation:	2 Corinthians 14:7 .
# Target:		2 Corinthians 11:3 .
#
# Spanish:	Véase Moisés 6:56 .
# Translation:	See Moses .
# Target:		See Moses 6:56 .
#
# Spanish:	Presidente Thomas S. Monson
# Translation:	President Thomas S. Monson
# Target:		President Thomas S. Monson
#
# Spanish:	donde durante la noche
# Translation:	How I was during the night
# Target:		Where God in the nighttime hours
#
# Spanish:	1 de octubre de 2017
# Translation:	October 01 , 2017
# Target:		October 01 , 2017
#
# Spanish:	Doctrina y Convenios 1:17 .
# Translation:	Doctrine and Covenants 1:17 .
# Target:		Doctrine and Covenants 1:17 .
#
# Spanish:	Véase 2 Nefi <unk> .
# Translation:	See 2 Nephi 32:5 .
# Target:		See 2 Nephi <unk> .
#
# Spanish:	La familia es de Dios
# Translation:	The Family Is
# Target:		The Family Is of God
#
# Spanish:	La Iglesia sigue creciendo .
# Translation:	The Church continues to grow .
# Target:		The Church continues to grow .
#
# Spanish:	¡ Ya no quiero desperdiciar
# Translation:	Do n’t want to start
# Target:		Now , I do not wish to waste
#
# Spanish:	Sesión del sábado por la tarde
# Translation:	Saturday Morning Session
# Target:		Saturday Afternoon Session
#
# Spanish:	Élder LeGrand R. Curtis Jr .
# Translation:	Elder LeGrand R. Curtis .
# Target:		Elder LeGrand R. Curtis Jr.
#
# Spanish:	¿ Cuál es el remedio ?
# Translation:	What is the remedy ?
# Target:		What is the remedy ?
#
# Spanish:	Seguir adelante con fe en Cristo
# Translation:	Following the faith in Christ
# Target:		Press Forward with Faith in Christ
#
# Spanish:	¿ Están dispuestos a trabajar ?
# Translation:	Are you willing to work ?
# Target:		Are you willing to work ?
#
# Spanish:	El juzgar corresponde al Señor .
# Translation:	The Lord ’s command .
# Target:		Judgment is the Lord ’s .
#
# Spanish:	Santiago 2:13 , edición SUD .
# Translation:	James , ed .
# Target:		James 2:13 , English Standard Version .
#
# Spanish:	cuando tentaciones <unk> con furor ,
# Translation:	When we are trying to move forward with words ,
# Target:		When you are discouraged , thinking all is lost ,
#
# Spanish:	Reunión General de la Sociedad de Socorro
# Translation:	Relief Society General Relief Society General Presidency
# Target:		General Relief Society Meeting
#
# Spanish:	¡ Nuestro progreso es Su obra !
# Translation:	Our progress is His work !
# Target:		Our progress is His work !
#
# Spanish:	Esos principios son espirituales y eternos .
# Translation:	These principles are spiritual principles and eternal principles .
# Target:		Those principles are spiritual and eternal .
#
# Spanish:	Pero ¿ qué hicieron las hermanas ?
# Translation:	But what sisters did ?
# Target:		But what did the sisters do ?
#
# Spanish:	Él conocía las pruebas que pasaríamos .
# Translation:	He knew that trials may require .
# Target:		He knew the trials we would face .
#
# Spanish:	Es una experiencia que agradezco haber sobrellevado
# Translation:	It is a experience I am to have experienced a few experience that I am a experience I am a experience I I am a experience .
# Target:		It is an experience I am grateful to have endured .
#
# Spanish:	El sostenimiento de los Oficiales de la Iglesia
# Translation:	The sustaining of the Church Officers
# Target:		The Sustaining of Church Officers
#
# Spanish:	Llenar nuestros hogares de luz y de verdad
# Translation:	Saving Our homes of light and truth
# Target:		Filling Our Homes with Light and Truth
#
# Spanish:	2 Nefi 2:14 ; 3 Nefi 9:15 .
# Translation:	2 Nephi 2:14 ; 3 Nephi 3 Nephi .
# Target:		2 Nephi 2:14 ; 3 Nephi 9:15 .
#
# Spanish:	Setentas Autoridades Generales ( en orden alfabético )
# Translation:	General Authorities ( General Authorities )
# Target:		General Authority Seventies ( in alphabetical order )
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	En el nombre de Jesucristo . Amén .
# Translation:	In the name of Jesus Christ , amen .
# Target:		In the name of Jesus Christ , amen .
#
# Spanish:	Él escuchará y responderá sus preguntas personales .
# Translation:	He will answer your personal questions .
# Target:		He will listen , and He will answer your personal questions .
#
# Spanish:	La Restauración cumple muchas de las profecías bíblicas .
# Translation:	The Restoration of the prophecies of the prophecies .
# Target:		The Restoration fulfills many biblical prophecies .
#
# Spanish:	Aceptaron de buena gana y volvieron a entrar .
# Translation:	They were good and they were to enter .
# Target:		They willingly agreed and went back in .
#
# Spanish:	Esta mañana celebramos Su victoria sobre la muerte .
# Translation:	This morning His victory over death .
# Target:		We celebrate this morning His victory over death .
#
# Spanish:	“ Escogidos para dar testimonio de mi nombre ”
# Translation:	“ A Testimony of My Name of my name ”
# Target:		“ Chosen to Bear Testimony of My Name ”
#
# Spanish:	“ cuán gran motivo tenemos para regocijarnos ” .
# Translation:	“ How great reason we have to come unto us . ”
# Target:		“ How great reason have we to rejoice . ”
#
# Spanish:	Ni en este mundo ni en el venidero .
# Translation:	Not this world or to come to come .
# Target:		Not in this world or in the world to come .
#
# Spanish:	También nos enseña cómo arrepentirnos cuando cometemos transgresiones .
# Translation:	We also teaches how to repent when we make mistakes .
# Target:		It also teaches us how to repent when violations have occurred .
#
# Spanish:	Pensar en el significado de dichos principios y doctrina .
# Translation:	Think about the meaning of the doctrine and doctrine .
# Target:		Think about their meaning .
#
# Spanish:	Primera Consejera de la Presidencia General de las Mujeres Jóvenes
# Translation:	First Counselor in the Young Women General Presidency
# Target:		First Counselor in the Young Women General Presidency
#
# Spanish:	<unk> y sorprendentemente , la mayoría bajó su mano .
# Translation:	They will require the same hand , the hand .
# Target:		Sadly and surprisingly , most hands went down .
#
# Spanish:	Cada aspecto de ese sagrado edificio era verdaderamente <unk> .
# Translation:	Each of that sacred building was truly a matter .
# Target:		Every aspect of this sacred building was truly exquisite .
#
# Spanish:	¡ Sé que el Libro de Mormón es verdadero !
# Translation:	I know that the Book of Mormon is true !
# Target:		I know that the Book of Mormon is true !
#
# Spanish:	¿ Deberíamos comprometernos a algo menos con el Señor ?
# Translation:	Do we understand something less than the Lord ?
# Target:		Should we make less of a commitment to the Lord ?
#
# Spanish:	Los malvados serán responsables de las atrocidades que cometan .
# Translation:	The Psalmist will be responsible for the many of us .
# Target:		The wicked will be held accountable for the atrocities they <unk> .
#
# Spanish:	No contestó … así que comencé a cantarle suavemente .
# Translation:	He replied , “ I began to sit on the floor .
# Target:		She did n’t answer … , so I began to sing softly to her .
#
# Spanish:	Al igual que ustedes , ¡ me encantan las Escrituras !
# Translation:	Like you , I love you !
# Target:		Like you , I love the scriptures !
#
# Spanish:	¿ A cuál de estas dos personas nos parecemos más ?
# Translation:	Why are those two of us who are more than we are ?
# Target:		Which of these two people are we most like ?
#
# Spanish:	Jeanene Watkins Scott , diario personal , abril de 1988 .
# Translation:	Jeanene Scott , personal , Apr. 1974 , 9 .
# Target:		Jeanene Watkins Scott , personal journal , Apr. 1988 .
#
# Spanish:	“ Edificios , el cielo , gente ” , respondí .
#
# Spanish:	¿ Podemos ejercer la fe para creer y para actuar en consecuencia ?
# Translation:	Can we exercise faith to believe and act in a result ?
# Target:		Can we exercise the faith to believe and to act accordingly ?
#
# Spanish:	Este es mi testimonio ; en el nombre de Jesucristo . Amén .
# Translation:	This is my testimony in the name of Jesus Christ , amen .
# Target:		This is my testimony in the name of Jesus Christ , amen .
#
# Spanish:	Esa difícil y trascendental decisión se tomó hace más de treinta años .
# Translation:	This difficult and has been the most important thing .
# Target:		That fateful , difficult decision was made more than 30 years ago .
#
# Spanish:	Sin embargo , antes del partido final , se jugaría una <unk> .
# Translation:	However , before the end of the end , it was a distant place .
# Target:		Prior to the final game , however , there was a <unk> game .
#
# Spanish:	Él ha prometido juntar a Sus hijos , y está con ustedes .
# Translation:	He has promised His children , and He is with you .
# Target:		He has promised to gather His children , and He is with you .
#
# Spanish:	Y testificaron a los Apóstoles que “ … verdaderamente ha resucitado el Señor
# Translation:	And they testified to the Apostles that “ the resurrected Lord hath risen the resurrected Lord hath risen the resurrected Lord .
# Target:		And then they testified to the Apostles that “ the Lord is risen indeed .
#
# Spanish:	<unk> la oferta , pero ella estaba muy bien donde se encontraba .
# Translation:	They were the bottom but she was very well .
# Target:		She was quite comfortable , thank you very much , right where she was .
#
# Spanish:	Debemos primeramente desear , anhelar y procurar la compañía del Espíritu Santo .
# Translation:	We must wish to accept and partake of the Holy Ghost .
# Target:		We first should desire , yearn for , and seek the companionship of the Holy Ghost .
#
# Spanish:	Había globos blancos llenos de helio para celebrar la vida de la joven .
# Translation:	There were a short of charity to choose to choose the young man .
# Target:		There were white <unk> balloons to celebrate her life .
#
# Spanish:	Esta experiencia se caracteriza por el inmediato e intenso reconocimiento de la luz .
# Translation:	This experience was found by the intense and felt the light of light .
# Target:		This experience was characterized by immediate and intense recognition of light .
#
# Spanish:	Una vez que las descubramos , Él nos ayudará a cumplir esas asignaciones .
# Translation:	One time we will help us to fulfill these assignments .
# Target:		Once we discover them , He will help us fulfill those assignments .
#
# Spanish:	¿ Cómo llevaron la leña para prender el fuego arriba en la montaña ?
# Translation:	How did the fire to follow the fire ?
# Target:		How did they carry the wood for the fire up the mountain ?
#
# Spanish:	2 Corintios 12:9 ; véase también Éter <unk> ; Doctrina y Convenios <unk> .
# Translation:	2 Corinthians 3:16 ; see also Ether 12:27 ; Doctrine and Covenants 88:3 .
# Target:		2 Corinthians 12:9 ; see also Ether <unk> ; Doctrine and Covenants <unk> .
#
# Spanish:	Su valiente decisión de creer en Él los bendecirá grandemente y para siempre .
# Translation:	Your choice to believe in Him will bless you and bless you .
# Target:		Your courageous decision to believe in Him will bless you immeasurably and forever .
#
# Spanish:	Ruego que tengamos esa maravillosa bendición de parte del Maestro al que servimos .
# Translation:	I pray that we have a wonderful blessing of the Master who serve .
# Target:		I pray that we will receive that wonderful benediction from the Master we serve .
#
# Spanish:	¿ Oran ustedes a su Padre Celestial como preparación para tomar decisiones importantes ?
# Translation:	Will you see your Heavenly Father ’s preparation for important decisions ?
# Target:		Do you prepare yourself to make important decisions by praying to your Heavenly Father ?
#
# Spanish:	Sí , la fe es una elección que se debe buscar y cultivar .
# Translation:	Yes , faith is a choice that should be and seek to develop and develop .
# Target:		Yes , faith is a choice , and it must be sought after and developed .
#
# Spanish:	Por respeto a nuestro albedrío , nunca es un <unk> fuerte ni enérgico .
# Translation:	For respect to our agency , it is never a strong and be strong .
# Target:		Out of respect for our agency , it is never a strong , forceful tug .
#
# Spanish:	Las dificultades que llegan presentan la verdadera prueba a nuestra capacidad de perseverar .
# Translation:	We have challenges that we become true faith .
# Target:		The difficulties which come to us present us with the real test of our ability to endure .
#
# Spanish:	En ese momento sentí como si me <unk> los brazos amorosos del Salvador .
# Translation:	At that moment I felt as I felt the Savior ’s arms .
# Target:		At that moment , brothers and sisters , I felt as if I was encircled in the Savior ’s loving arms .
#
# Spanish:	Al percibir sus pensamientos , el Salvador se dirigió a ellos y les dijo :
# Translation:	As you can , the Savior turned to them and then were opened to them :
# Target:		Perceiving their thoughts , the Savior addressed them , saying :
#
# Spanish:	Véase Guía para el Estudio de las Escrituras , “ Ordenanzas ” , scriptures.lds.org .
# Translation:	See Bible Dictionary , “ The scriptures , ” Ensign or Liahona , Jan. 2001 .
# Target:		See Guide to the Scriptures , “ Ordinances , ” scriptures.lds.org .
#
# Spanish:	( 29 ) La madre de L. Tom Perry le enseña cuando es pequeño .
# Translation:	( 29 ) The Primary L. Tom Perry teaches him when he is .
# Target:		( 29 ) Young L. Tom Perry is taught by his mother .
#
# Spanish:	¿ En qué consiste la responsabilidad de ser miembro de la Iglesia de Jesucristo ?
# Translation:	What is the responsibility of a member of the Church of Jesus Christ ?
# Target:		What responsibility do we have as members of the Church of Jesus Christ ?
#
# Spanish:	“ Pues aun cuando ellos se <unk> , yo nunca me olvidaré de ti ”
# Translation:	“ But even when they were a sign of me , I will never forget thee . ”
# Target:		“ Yea , they may forget , yet will I not forget thee .
#
# Spanish:	Los vamos recibiendo cuando los necesitamos : línea por línea y precepto por precepto .
# Translation:	We are prepared by the line : We are precept and precept upon precept .
# Target:		They come when they are needed : line upon line and precept upon precept .
#
# Spanish:	Está claro que el lenguaje del corazón es de mucho valor para las personas .
# Translation:	It is clear that the language is much of the worth of people .
# Target:		It is clear that the language of the heart is precious to all people .
#
# Spanish:	Entonces todas las cosas que de mí deseares … en rectitud … recibirás ” .
# Translation:	Then all things that you will know of righteousness … … … shall receive . ”
# Target:		“ Then whatsoever you desire of me in righteousness , … you shall receive . ”
#
# Spanish:	En la vida preterrenal , supimos que necesitaríamos un período en la vida mortal .
# Translation:	In the premortal life , we learned that we had a period in mortality .
# Target:		In the premortal life , we learned that we would need a period of mortality .
#
# Spanish:	Nada consideran con más sagrada reflexión aquellos que conocen el significado de esta autoridad .
# Translation:	Nothing will be more than those who know the meaning of this life .
# Target:		Nothing is regarded with more sacred contemplation by those who know the significance of this authority .
#
# Spanish:	<unk> en lo que sostendrá una paz duradera en la mente y el corazón .
# Translation:	Let us be a peace that will sustain the peace and heart .
# Target:		Let us instead focus on those things that will sustain a lasting peace of mind and heart .
#
# Spanish:	Continuamente buscamos Su guía en la oración , las Escrituras y los susurros del Espíritu Santo .
# Translation:	We seek His guidance in prayer , and the scriptures , and the Holy Ghost .
# Target:		We continually seek His guidance in prayer , in the scriptures , and in the whisperings of the Holy Ghost .
#
# Spanish:	Los líderes enseñan y testifican acerca de la doctrina sobre la cual se basa esta sagrada obra .
# Translation:	The leaders and testify of the doctrine of which is found in this sacred work .
# Target:		Leaders teach and testify of the doctrine undergirding this sacred work .
#
# Spanish:	En ocasiones , el Espíritu ablandó el corazón de miles y <unk> el odio con el amor .
# Translation:	Sometimes the Spirit would be the hearts of thousands of thousands of being with love .
# Target:		The Spirit at times softened the hearts of thousands and replaced hatred with love .
#
# Spanish:	Entre una batalla y otra , el capitán Moroni dirigió la <unk> de las ciudades menos protegidas .
# Translation:	Among a battle and other side of Moroni ’s creations were opened to the cities .
# Target:		In between the many battles , Captain Moroni directed fortification of the weakest cities .
#
# Spanish:	Templos dedicados durante 2014 ( Fort Lauderdale , Florida ; Gilbert , Arizona y Phoenix , Arizona )
# Translation:	Temples in Operation ( 2014 ) , Salt Lake City .
# Target:		Temples Dedicated during 2014 ( Fort Lauderdale Florida , Gilbert Arizona , and Phoenix Arizona )
#
# Spanish:	No obstante , sin paciencia no podemos agradar a Dios ; no podemos llegar a ser perfectos .
# Translation:	But without patience , we can not be God . We can not become perfect .
# Target:		Nevertheless , without patience , we can not please God ; we can not become perfect .
#
# Spanish:	El élder Russell M. Nelson sugirió que los niños pueden dibujar árboles familiares ( página 91 ) .
# Translation:	Elder Russell M. Nelson suggested that the family can build the fire ( page 94 ) .
# Target:		Elder Russell M. Nelson suggested that children can draw a family tree ( page 91 ) .
#
# Spanish:	Sus padres tuvieron por lo menos un indicio de las bendiciones que podrían tener a su disposición .
# Translation:	His parents had a less - term blessings of the blessings they might have its blessings .
# Target:		Their parents had at least an inkling of the blessings that could be made available to them .
#
# Spanish:	El Salvador trajo a esta tierra un mensaje de amor y buena voluntad a todos los hombres .
# Translation:	The Savior brought to this message of love and the good and to all men .
# Target:		The Savior brought to this earth a message of love and goodwill to all men and women .
#
# Spanish:	Cada vez que veía la luz , Sailor tenía constancia de que estaba en el camino correcto .
# Translation:	Each time I could see the light of the right way that was the right path .
# Target:		Whenever she could see the light , Sailor had evidence that she was on the right path .
#
# Spanish:	Tal vez el primer deber del sacerdocio que cumpla sea repartir la Santa Cena el próximo domingo .
# Translation:	Perhaps the first priesthood duty to pass the sacrament is the sacrament Sunday .
# Target:		He may expect that his first performance of a priesthood duty will be passing the sacrament next Sunday .
#
# Spanish:	Estos siempre presentes pesimistas prefieren derribar en vez de elevar , y ridiculizar en vez de edificar .
# Translation:	These are always different from being honest and to lift up and to build .
# Target:		These ever - present naysayers prefer to tear down rather than elevate and to ridicule rather than uplift .
#
# Spanish:	Todos nos encontramos en diferentes lugares del sendero , y debemos <unk> los unos a los otros .
# Translation:	We all are different in different places of the path , and we must be able to another .
# Target:		We are all at different places on the path , and we need to minister to one another accordingly .
#
# Spanish:	Con ese poder podemos contribuir a preparar el mundo para la Segunda Venida de nuestro Salvador Jesucristo .
# Translation:	With that power we can prepare the world for the Second Coming of our Savior , Jesus Christ .
# Target:		With that power , we can help prepare the world for the Second Coming of our Savior , Jesus Christ .
#
# Spanish:	“ Los líderes de esta Iglesia conocen los problemas , las preocupaciones y los desafíos de ustedes .
# Translation:	“ The Church of this Church , you know the challenges of challenges and challenges .
# Target:		“ The leaders of this Church are no strangers to your issues , to your concerns , and to your challenges .
#
# Spanish:	Como no había una escalera para trepar , les tomó un buen rato para que todos subieran .
# Translation:	As a number of the top , He took a good thing to do all who would be able to make .
# Target:		Assuming there was no outside <unk> for them to climb , it would have taken them quite some time to get everyone onto the roof .
#
# Spanish:	Si le prestamos servicio durante el tiempo que sea necesario y lo hacemos con diligencia , seremos cambiados .
# Translation:	If we serve during the time we may be necessary and make it with diligence , we will be changed .
# Target:		As we serve Him long enough and with diligence , we will be changed .
#
# Spanish:	A lo largo de la historia del mundo , la mujer siempre ha sido maestra de valores morales .
# Translation:	Throughout the history of the world , the woman has always been always a leader .
# Target:		Throughout the history of the world , women have always been teachers of moral values .
#
# Spanish:	“ Porque si perdonáis a los hombres sus ofensas , os perdonará también a vosotros vuestro Padre Celestial .
# Translation:	“ For if ye shall be your men , your willingness to forgive your Heavenly Father .
# Target:		“ For if ye forgive men their trespasses , your heavenly Father will also forgive you :
#
# Spanish:	pero el Hijo de Dios se levantó del sepulcro a fin de que todos podamos vencer la muerte .
# Translation:	But the Son of God ’s Son were raised to overcome the grave .
# Target:		But the Son of God rose from the grave , that we may all overcome death .
#
# Spanish:	Y un testimonio no siempre tiene que empezar con la frase : “ Les doy mi testimonio ” .
# Translation:	And a testimony has not always been to start with the phrase “ I give me my testimony . ”
# Target:		And a testimony need not always begin with the phrase “ I bear you my testimony . ”
#
# Spanish:	Desde luego que se consideró como una gran bendición que el señor Hord hubiera decidido hacer ese viaje .
# Translation:	From then he was called as a great blessing that would have left that would have been to do .
# Target:		Of course it was deemed a great blessing that Mr. Hord had decided to make that trip .
#
# Spanish:	“ Porque he aquí , las palabras de Cristo os dirán todas las cosas que debéis hacer ” .
# Translation:	“ For behold , the words of Christ will tell you all things that ye must do . ”
# Target:		“ For behold , the words of Christ will tell you all things what ye should do . ”
#
# Spanish:	Ruego que sigamos el ejemplo del Salvador , quien habló de tolerancia y amabilidad durante todo Su ministerio .
# Translation:	I pray that we follow the Savior ’s example , who spoke of a Christian discipleship .
# Target:		May we follow the example of the Savior , who spoke with tolerance and kindness throughout His ministry .
#
# Spanish:	Un domingo , el obispo de Alex lo encontró solo y muy angustiado en un salón de clase .
# Translation:	A bishop ’s bishop ’s bishop ’s . She was very very different .
# Target:		One Sunday , Alex ’s bishop found him alone in a classroom in a state of great distress .
#
# Spanish:	Recordemos también que nuestros hijos y nietos <unk> nuestro amor por la cantidad de tiempo que les dedicamos .
# Translation:	Remember that our children and our grandchildren will be the amount of time we are trying to share .
# Target:		Let us remember that our children and grandchildren measure our love by how much devoted time we give them .
# Translation:	Music by a Primary choir from Relief Society , Young Women and the Young Women of stakes of the stakes of the University of Utah , USA ; Linda Margetts , organist : “ Children ’s Songbook , pub . Jackman ; “ Sweet Is a Children ’s Plan , ” Hymns , no . Jackman ; “ The
# Target:		Music by a combined Primary , Young Women , and Relief Society choir from stakes in southern Cache Valley , Utah ; Claudia <unk> , director ; Bonnie Goodliffe , organist ; Sarah Johnson , <unk> : “ Come , Ye Children of the Lord , ” Hymns , no . 58 ; medley , arr . Mohlman , unpublished : “ I Will Follow God ’s Plan , ” Children ’s Songbook , 164 , and “ Faith in Every Footstep , ” Dayley , accompanied by <unk> and organ ; “ As Zion ’s Youth in Latter Days , ” Hymns , no . 256 , arr . Kasen , pub . by Jackman ; “ Dearest Children , God Is Near You , ” Hymns , no . 96 , arr . Watkins , unpublished ; “ Go Forth with Faith , ” Hymns , no . 263 , descant arr . <unk> , unpublished .
#
# Spanish:	Jorge M. <unk> , <unk> S. <unk> , <unk> <unk> , Jorge D. <unk> , Marcelo <unk> , Fernando E. <unk> , Gabriel A. Campos , <unk> - <unk> <unk> , <unk> A. Cooper , <unk> da Costa , John C. Dalton , Kevin R. Duncan , Randy D. Funk , Robert H. <unk> , Gerrit W. Gong , <unk> J. <unk> , S. <unk> <unk> , Ronald J. <unk> , Stephen W. Hansen , <unk> <unk> ( Philip ) Ho , Patrick Kearon , <unk> H. <unk> , Larry R. Lawrence , Robert W. <unk> , F. <unk> <unk> , Juan A. <unk> , Per G. Malm , Carlos S. <unk> , Alexander A. <unk> , A. <unk> <unk> , Melvin R. Perkins , James C. Perry , John C. Pingree , <unk> M. Reyes , D. Chad Richardson , <unk> W. <unk> , Hans T. Sorensen , John C. <unk> , Donald P. Tenney , G. <unk> Walker , Johann A. <unk> y Kazuhiko Yamashita .
# Translation:	Note , they are able to dedicate , to The Miracle , trans , to Spencer W. Hunter , director , Les Misérables , to the organ .
# Target:		Those who wish to join us in expressing our gratitude for their excellent service , please manifest it .

# %% [markdown]
# <div id="disqus_thread"></div>
# <script>
#     /**
#      *  RECOMMENDED CONFIGURATION VARIABLES: EDIT AND UNCOMMENT THE SECTION BELOW TO INSERT DYNAMIC VALUES FROM YOUR PLATFORM OR CMS.
#      *  LEARN WHY DEFINING THESE VARIABLES IS IMPORTANT: https://disqus.com/admin/universalcode/#configuration-variables
#      */
#     /*
#     var disqus_config = function () {
#         this.page.url = PAGE_URL;  // Replace PAGE_URL with your page's canonical URL variable
#         this.page.identifier = PAGE_IDENTIFIER; // Replace PAGE_IDENTIFIER with your page's unique identifier variable
#     };
#     */
#     (function() {  // REQUIRED CONFIGURATION VARIABLE: EDIT THE SHORTNAME BELOW
#         var d = document, s = d.createElement('script');
#
#         s.src = 'https://EXAMPLE.disqus.com/embed.js';  // IMPORTANT: Replace EXAMPLE with your forum shortname!
#
#         s.setAttribute('data-timestamp', +new Date());
#         (d.head || d.body).appendChild(s);
#     })();
# </script>
# <noscript>Please enable JavaScript to view the <a href="https://disqus.com/?ref_noscript" rel="nofollow">comments powered by Disqus.</a></noscript>
